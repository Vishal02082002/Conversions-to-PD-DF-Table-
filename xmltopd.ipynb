# %%
import xml.etree.ElementTree as ET

# %%
import pandas as pd

# %%
from datetime import datetime

# %%
import requests

# %%
from dateutil.parser import parse as date_parse

# %%
#parse the XML file
#tree=ET.parse('Data_Sample .xml')
url = 'https://github.com/Vishal02082002/Conversions-to-PD-DF-Table-/blob/main/Data_Sample.xml'
# Fetch the XML file from the GitHub link
response = requests.get(url)
if response.status_code == 200:
    print("The XML file is successfully loaded.")
else:
    print(f"Failed to load XML file. Status code: {response.status_code}")
    exit(1)
# Out:
# The XML file is successfully loaded.

# %%
root = tree.getroot()

# %%
# initialize an empty list to store data
data = []

# %%
# define a recursive function to parse the xml tree
def parse_element(element, item):
    if len(list(element))==0:
        item[element.tag] = element.text
    else:
        for child in list(element):
            parse_element(child,item)

# %%
# Iterate through the xml tree and parse the elements

for child in root:
    item={}
    parse_element(child,item)
    data.append(item)

# %%
data
# Out:
# [{'Dealers_lot': 'true',
#   'dealer_id': '1',
#   'in_compliance': 'false',
#   'machine_id': '11',
#   'machine_sold_status': 'Sold ',
#   'machine_status': 'Dealer Rental Fleet',
#   'model_no': '644P',
#   'modified_date': '03-05-2024'},
#  {'Dealers_lot': 'true',
#   'dealer_id': '2',
#   'in_compliance': 'true',
#   'machine_id': '13',
#   'machine_sold_status': 'Unsold',
#   'machine_status': 'Dealer Presold',
#   'model_no': '1775NT',
#   'modified_date': '04-05-2024'},
#  {'Dealers_lot': 'false',
#   'dealer_id': '3',
#   'in_compliance': 'true',
#   'machine_id': '15',
#   'machine_sold_status': 'Sold ',
#   'machine_status': 'Stock',
#   'model_no': '54H',
#   'modified_date': '05-05-2024'},
#  {'Dealers_lot': 'true',
#   'dealer_id': '4',
#   'in_compliance': 'false',
#   'machine_id': '17',
#   'machine_sold_status': 'Unsold',
#   'machine_status': 'Dealer Rental Fleet',
#   'model_no': '5435T',
#   'modified_date': '06-05-2024'},
#  {'Dealers_lot': 'false',
# ...

# %%
# Filter the data based on the conditions
'''filtered_data = []
for item in data:
    if 'modified_date' in item and 'in_compliance' in item and 'machine_sold_status' in item:
        try:
            modified_date = datetime.strptime(item['modified_date'], '%d-%m-%Y')
            in_compliance = item['in_compliance'].strip().lower() == 'true'
            machine_sold_status = item['machine_sold_status'].strip().lower() == 'sold'
            if modified_date > datetime.strptime('12-05-2024', '%d-%m-%Y') and in_compliance and machine_sold_status:
                filtered_data.append(item)
        except ValueError:
            # Handle the case where the date format is incorrect
            pass'''
# Out:
# "filtered_data = []\nfor item in data:\n    if 'modified_date' in item and 'in_compliance' in item and 'machine_sold_status' in item:\n        try:\n            modified_date = datetime.strptime(item['modified_date'], '%d-%m-%Y')\n            in_compliance = item['in_compliance'].strip().lower() == 'true'\n            machine_sold_status = item['machine_sold_status'].strip().lower() == 'sold'\n            if modified_date > datetime.strptime('12-05-2024', '%d-%m-%Y') and in_compliance and machine_sold_status:\n                filtered_data.append(item)\n        except ValueError:\n            # Handle the case where the date format is incorrect\n            pass"

# %%
df=pd.DataFrame(data)

print("All of the rows and colomns are defined now")
# Out:
# All of the rows and colomns are defined now

# %%
#df=pd.DataFrame(filtered_data)

print("All of the rows and colomns are defined now")
# Out:
# All of the rows and colomns are defined now

# %%
df
# Out:
#    Dealers_lot dealer_id in_compliance machine_id machine_sold_status  \
# 0         true         1         false         11               Sold
# 1         true         2          true         13              Unsold
# 2        false         3          true         15               Sold
# 3         true         4         false         17              Unsold
# 4        false         5          true         19               Sold
# 5         true         6         false         21               Sold
# 6        false         7          true         23              Unsold
# 7         true         8          true         25               Sold
# 8         true         9         false         27               Sold
# 9         true        10         false         29              Unsold
# 10       false        11          true         31              Unsold
# 11        true        12         false         33               Sold
# ...

# %%
# Get a list of attributes
attributes = df.columns.tolist()
print("\nList of attributes:")
print(attributes)
# Out:
# List of attributes:
# ['Dealers_lot', 'dealer_id', 'in_compliance', 'machine_id', 'machine_sold_status', 'machine_status', 'model_no', 'modified_date']

# %%
# Get the count of the number of rows and columns
num_rows, num_columns = df.shape
print(f"\nNumber of rows: {num_rows}")
print(f"Number of columns: {num_columns}")
# Out:
# Number of rows: 20
# Number of columns: 8

# %%
# Get the volume of data
data_volume = df.size
print(f"\nVolume of data (total elements): {data_volume}")
# Out:
# Volume of data (total elements): 160

# %%
# Function to classify data types
def classify_data_type(series):
    try:
        pd.to_numeric(series.dropna())
        return 'Number'
    except ValueError:
        pass

    try:
        series.dropna().apply(date_parse)
        return 'Date'
    except (ValueError, TypeError):
        pass

    if series.dropna().str.contains('[^a-zA-Z0-9]').any():
        return 'Alphanumeric'

    return 'String'

# Get the types of data for all the attributes
data_type_classification = {col: classify_data_type(df[col]) for col in df.columns}
print("\nData types for all attributes:")
print(data_type_classification)
# Out:
# Data types for all attributes:
# {'Dealers_lot': 'String', 'dealer_id': 'Number', 'in_compliance': 'String', 'machine_id': 'Number', 'machine_sold_status': 'Alphanumeric', 'machine_status': 'Alphanumeric', 'model_no': 'String', 'modified_date': 'Date'}
